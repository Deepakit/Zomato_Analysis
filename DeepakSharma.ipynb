# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="edaicon.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=24px>
#                     <b>Exploratory Data Analysis
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Problem Statement
#
# The zomato exploratory data analysis is for the foodies to find the best restaurants, value for money restaurants in their locality. It also helps to find their required cuisines in their locality.

# %% [markdown]
# ## Data Definition
#
# **res_id**: The code given to a restaurant (Categorical)
#
# **name**: Name of the restaurant (Categorical)
#
# **establishment**: Represents the type of establishment (Categorical)
#
# **url**: The website of the restaurant (Categorical)
#
# **address**: The address of the restaurant (Categorical)
#
# **city**: City in which the restaurant located (Categorical)
#
# **city_id**: The code given to a city (Categorical)
#
# **locality**: Locality of the restaurant (Categorical)
#
# **latitude**: Latitude of the restaurant (Categorical)
#
# **longitude**: Longitude of the restaurant (Categorical)
#
# **zipcode**: Zipcode of the city in which the restaurant located (Categorical)
#
# **country_id**: Country code in which the restaurant located (Categorical)
#
# **locality_verbose**: Locality along with the city in which the restaurant located (Categorical)
#
# **cuisines**: The cuisines a restaurant serves (Categorical)
#
# **timings**: The working hours of a restaurant (Categorical)
#
# **average_cost_for_two**: The average amount expected for 2 people (Numerical)
#
# **price_range**: The categories for average cost (Categories - 1,2,3,4) (Categorical)
#
# **currency**: The currency in which a customer pays (Categorical)
#
# **highlights**: The facilities of the restaurant (Categorical)
#
# **aggregate_rating**: The overall rating a restaurant has got (Numerical)
#
# **rating_text**: Categorized ratings (Categorical)
#
# **votes**: Number of votes received by the restaurant from customers (Numerical)
#
# **photo_count**: The number of photos of a restaurant (Numerical)
#
# **opentable_support**: Restaurant reservation from Opentable (Categorical)
#
# **delivery**: The restaurant deliver an order or not (Categorical)
#
# **takeaway**: The restaurant allows  a 'takeaway' of an order or not (Categorical)

# %% [markdown]
# ## Table of Contents
#
# 1. **[Import Libraries](#import_lib)**
# 2. **[Set Options](#set_options)**
# 3. **[Read Data](#Read_Data)**
# 4. **[Understand  and Prepare the Data](#Understand_Data)**
# 5. **[Understand the variables](#Understanding_variables)**
# 6. **[Check for Missing Values](#missing)**
# 7. **[Study Correlation](#correlation)**
# 8. **[Detect Outliers](#outliers)**
# 9. **[Create a new variable 'region'](#region)**
# 10. **[Some more analysis](#more)**

# %% [markdown]
# <a id='import_lib'></a>
# ## 1. Import Libraries

# %% [markdown]
# <table align ="left">
#     <tr>
#         <td width="8%">
#             <img src="todo.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> Import the required libraries and functions
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <a id='set_options'></a>
# ## 2. Set Options

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="todo.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>Make necessary changes to :<br><br>
# Set the working directory
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id='Read_Data'></a>
# ## 3. Read Data

# %%
df_zomato=pd.read_csv('ZomatoRestaurantsIndia.csv')
df_zomato.head(3)
# Out:
#     res_id                            name establishment  \
# 0  3400299                     Bikanervala   Quick Bites
# 1  3400005  Mama Chicken Mama Franky House   Quick Bites
# 2  3401013                   Bhagat Halwai   Quick Bites
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# 2  62/1, Near Easy Day, West Shivaji Nagar, Goalp...  Agra       34
#
#      locality   latitude  longitude    ...    price_range  currency  \
# 0    Khandari  27.211450  78.002381    ...              2       Rs.
# 1  Agra Cantt  27.160569  78.011583    ...              2       Rs.
# 2    Shahganj  27.182938  77.979684    ...              1       Rs.
#
#                                           highlights aggregate_rating  \
# 0  Lunch, Takeaway Available, Credit Card, Dinner...              4.4
# 1  Delivery, No Alcohol Available, Dinner, Takeaw...              4.4
# 2  No Alcohol Available, Dinner, Takeaway Availab...              4.2
#
#   rating_text  votes  photo_count opentable_support delivery  takeaway
# 0   Very Good    814          154               0.0       -1        -1
# 1   Very Good   1203          161               0.0       -1        -1
# 2   Very Good    801          107               0.0        1        -1
#
# [3 rows x 26 columns]

# %% [markdown]
# <a id='Understand_Data'></a>
# ## 4. Understand  and Prepare the Data

# %% [markdown]
# A well-prepared data proves beneficial for analysis as it limits errors and inaccuracies that can occur during analysis. The processed data is more accessible to users.<br> <br>
#                          Data understanding is the process of getting familiar with the data, to identify data type, to discover first insights into the data, or to detect interesting subsets to form hypotheses about hidden information. Whereas, data preparation is the process of cleaning and transforming raw data before analysis. It is an important step before processing and often involves reformatting data, making corrections to data. <br> <br>
#                         Data preparation is often a lengthy process, but it is essential as a prerequisite to put data in context to get insights and eliminate bias resulting from poor data quality.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="todo.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> Analyze and prepare data:<br>
#                         1. Check dimensions of the dataframe <br>
#                         2. View the head of the data<br>
#                         3. Note the redundant variables and drop them <br>
#                         4. Check the data types. Refer to data definition to ensure your data types are correct. If data types are not as per business context, change the data types as per requirement <br>
#                         5. Check for duplicates<br>
#                         Note: It is an art to explore data and one will need more and more practice to gain expertise in this area
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### -------------------------*** Provide the inference's from the output of every code executed.***----------------------------

# %% [markdown]
# **1. Check dimensions of the dataframe in terms of rows and columns**

# %%
print(df_zomato.shape)
df_zomato.dtypes
# Out:
# (211944, 26)
# res_id                    int64
# name                     object
# establishment            object
# url                      object
# address                  object
# city                     object
# city_id                   int64
# locality                 object
# latitude                float64
# longitude               float64
# zipcode                  object
# country_id                int64
# locality_verbose         object
# cuisines                 object
# timings                  object
# average_cost_for_two      int64
# price_range               int64
# currency                 object
# highlights               object
# aggregate_rating        float64
# rating_text              object
# votes                     int64
# photo_count               int64
# opentable_support       float64
# delivery                  int64
# takeaway                  int64
# dtype: object

# %% [markdown]
# **2. View the head of the data**

# %%
df_zomato.head()
# Out:
#     res_id                            name  establishment  \
# 0  3400299                     Bikanervala    Quick Bites
# 1  3400005  Mama Chicken Mama Franky House    Quick Bites
# 2  3401013                   Bhagat Halwai    Quick Bites
# 3  3400290                   Bhagat Halwai    Quick Bites
# 4  3401744     The Salt Cafe Kitchen & Bar  Casual Dining
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# 2  62/1, Near Easy Day, West Shivaji Nagar, Goalp...  Agra       34
# 3  Near Anjana Cinema, Nehru Nagar, Civil Lines, ...  Agra       34
# 4        1C,3rd Floor, Fatehabad Road, Tajganj, Agra  Agra       34
#
#       locality   latitude  longitude    ...    price_range  currency  \
# 0     Khandari  27.211450  78.002381    ...              2       Rs.
# 1   Agra Cantt  27.160569  78.011583    ...              2       Rs.
# 2     Shahganj  27.182938  77.979684    ...              1       Rs.
# 3  Civil Lines  27.205668  78.004799    ...              1       Rs.
# 4      Tajganj  27.157709  78.052421    ...              3       Rs.
#
#                                           highlights aggregate_rating  \
# 0  Lunch, Takeaway Available, Credit Card, Dinner...              4.4
# 1  Delivery, No Alcohol Available, Dinner, Takeaw...              4.4
# 2  No Alcohol Available, Dinner, Takeaway Availab...              4.2
# 3  Takeaway Available, Credit Card, Lunch, Delive...              4.3
# 4  Lunch, Serves Alcohol, Cash, Credit Card, Dinn...              4.9
#
#   rating_text  votes  photo_count opentable_support delivery  takeaway
# 0   Very Good    814          154               0.0       -1        -1
# 1   Very Good   1203          161               0.0       -1        -1
# 2   Very Good    801          107               0.0        1        -1
# 3   Very Good    693          157               0.0        1        -1
# 4   Excellent    470          291               0.0        1        -1
#
# [5 rows x 26 columns]

# %% [markdown]
# **3. Note the redundant variables and drop them**

# %%
#First drop all the duplicate rows
df=df_zomato.copy()  # Copy the original dataframe

df1=df_zomato.drop_duplicates()

print(df1.shape)

#Columns currency , country_id have same value for all rows,they can be dropped.Column url does not give much information and locality_verbose is a repetitive column.

df1.drop(['url','currency','country_id','locality_verbose','opentable_support','address'],axis=1,inplace=True)
print(df1.shape)
# Out:
# (60417, 26)
# (60417, 20)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# **4. Check the data types. Refer to data definition to ensure your data types are correct. If data types are not as per business context, change the data types as per requirement**

# %%
print(df1.dtypes)
# Out:
# res_id                    int64
# name                     object
# establishment            object
# city                     object
# city_id                   int64
# locality                 object
# latitude                float64
# longitude               float64
# zipcode                  object
# cuisines                 object
# timings                  object
# average_cost_for_two      int64
# price_range               int64
# highlights               object
# aggregate_rating        float64
# rating_text              object
# votes                     int64
# photo_count               int64
# delivery                  int64
# takeaway                  int64
# dtype: object

# %% [markdown]
# #### Change the incorrect data type

# %%
df1[['res_id','delivery','takeaway']]=df1[['res_id','delivery','takeaway']].astype('object')
df1.dtypes
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# res_id                   object
# name                     object
# establishment            object
# city                     object
# city_id                   int64
# locality                 object
# latitude                float64
# longitude               float64
# zipcode                  object
# cuisines                 object
# timings                  object
# average_cost_for_two      int64
# price_range               int64
# highlights               object
# aggregate_rating        float64
# rating_text              object
# votes                     int64
# photo_count               int64
# delivery                 object
# takeaway                 object
# dtype: object

# %% [markdown]
# **5. Check for Duplicates**

# %%
dup_len=df1[df1.duplicated(['res_id'],keep=False)]
print(len(dup_len))

df1.drop_duplicates(subset='res_id',keep=False,inplace=True)
df1.shape
# Out:
# 9423
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# (50994, 21)

# %% [markdown]
# <a id = 'Understanding_variables'> </a>
# ## 5. Understand the variables

# %% [markdown]
# **1. Variable 'name'**

# %%
name_count=df1['name'].value_counts()
print(len(name_count))

df1['name'].value_counts()[:10].plot(kind='bar')
plt.title("Top restaurant chain in Country",weight="bold")
plt.ylabel("Name")
plt.xlabel("Count")
plt.show()
# Out:
# 7530

# %% [markdown]
# **2. Variable 'establishment'**

# %%
estab_count=df1['establishment'].unique()
print(len(estab_count))

#var=df1.groupby(['establishment']).count()
#print(var.head(2))

print("Mode is ",df1['establishment'].mode())
sns.countplot(df1['establishment'])
plt.title("Count of Type of Restaurant",weight='bold')
plt.xticks(rotation=90)

plt.show()
# Out:
# 24
# Mode is  0    Casual Dining
# dtype: object

# %% [markdown]
# **3. Variable 'city'**

# %%
city_count=df1['city'].unique()
print("No. of differen cities are ",len(city_count))

city_mode=df1['city'].mode()
print("Most no. of restaurants are in ",city_mode)

print(df1['city'].isnull().sum())

fig,ax=plt.subplots(figsize=(18,6))
sns.countplot(df1['city'],ax=ax)
plt.xticks(rotation=90)
plt.show()
# Out:
# No. of differen cities are  98
# Most no. of restaurants are in  0    Bangalore
# dtype: object
# 0

# %% [markdown]
# **Let us find the count of restaurants in each city**

# %%
#Visualization
fig,ax=plt.subplots(figsize=(14,18))
df1.city.value_counts().plot(kind='barh',ax=ax)
plt.title("Restaurant count in city",weight="bold")
plt.xlabel("Count")
plt.ylabel("City")
plt.show()

#Showing Numbers
df1.groupby('city')['name'].count().sort_values()
# Out:
# city
# Udupi              1
# Darjeeling         1
# Gangtok            1
# Vellore            2
# Neemrana           2
# Mussoorie          3
# Palakkad           3
# Junagadh           3
# Nainital           3
# Salem              3
# Amravati           4
# Ooty               5
# Trivandrum         5
# Kharagpur          5
# Greater Noida      5
# Rishikesh          6
# Tirupati           7
# Pushkar            8
# Thrissur           8
# Manali             9
# Manipal            9
# Jhansi             9
# Gorakhpur          9
# Gandhinagar        9
# Guntur             9
# Dharamshala       10
# Kolhapur          10
# Jamnagar          10
# Meerut            11
# Shimla            12
#                 ...
# Allahabad         67
# Noida             71
# Coimbatore        76
# Patna             78
# Guwahati          79
# Dehradun          84
# Bhopal            88
# Bhubaneshwar      90
# Mangalore         93
# Kochi            108
# Udaipur          109
# Vadodara         115
# Jabalpur         119
# Surat            127
# Nagpur           135
# Gurgaon          159
# Goa              184
# Indore           197
# Chandigarh       211
# Ludhiana         221
# Hyderabad        294
# Lucknow          326
# Ahmedabad        378
# Chennai          410
# Kolkata          461
# Jaipur           473
# New Delhi        582
# Pune             656
# Mumbai           725
# Bangalore        819
# Name: name, Length: 95, dtype: int64

# %% [markdown]
# **4. Variable 'locality'**

# %%
print("Total diff. types of locality are:",len(df['locality'].unique()),"\n")

df1.groupby('city')['locality'].value_counts()[:10].plot(kind='pie')
var=df1.groupby('city')['locality'].value_counts()
print('Count of localities in diff. city:\n',var)
# Out:
# Total diff. types of locality are: 3731
#
# Count of localities in diff. city:
#  city      locality
# Agra      Sikandra                                               130
#           Tajganj                                                130
#           Civil Lines                                            111
#           Kamla Nagar                                             81
#           Shahganj                                                64
#           Agra Cantt                                              57
#           Mantola                                                 34
#           Dayal Bagh                                              28
#           Khandari                                                26
#           Rakabganj                                               26
#           Arjun Nagar                                              8
#           Lohamandi                                                8
#           Kuberpur                                                 7
#           Jaypee Palace Hotel, Tajganj                             6
#           Trans Yamuna                                             6
#           ITC Mughal, Tajganj                                      5
#           Radisson Blu, Tajganj                                    5
#           Hotel Clarks Shiraz, Agra Cantt                          4
#           The Gateway Hotel, Tajganj                               4
#           Crystal Sarovar Premier, Tajganj                         3
#           Hotel Pushp Villa, Tajganj                               3
#           Mansingh Palace, Tajganj                                 3
#           Ramada Plaza, Tajganj                                    3
#           The Oberoi Amarvilas, Tajganj                            3
#           Trident Hotel, Tajganj                                   3
#           DoubleTree by Hilton Hotel Agra, Tajganj                 2
#           Four Points by Sheraton Agra, Tajganj                    2
#           Hotel Amar, Tajganj                                      2
#           Hotel Howard Plaza, Tajganj                              2
#           Hotel Metro, Civil Lines                                 2
#                                                                 ...
# Vizag     Four Points By Sheraton, Waltair Uplands                 2
#           Hotel Diamond’s Pearl, Dwaraka Nagar                     2
#           Hotel Haritha                                            2
#           Simhachalam                                              2
#           Swagrama Food Court                                      2
#           The Landmark                                             2
#           Vepagunta                                                2
#           Vishalaksmi Nagar                                        2
#           Vizag Drive In, Lawsons Bay                              2
#           Ambica Sea Green, Kirlampudi Layout                      1
#           Been Food Junction, MVP Colony                           1
#           Best Western Ramachandra Hotel, Gajuwaka                 1
#           Quality Inn                                              1
#           RTC Area                                                 1
#           Venkojipalem                                             1
# Zirakpur  VIP Road                                                40
#           Ambala Road                                             32
#           Dhakoli                                                 23
#           Dera Bassi                                              12
#           Chandigarh Road                                          9
#           Utrathiya                                                7
#           Namaste Chandigarh Complex, Dera Bassi                   6
#           Lohgarh                                                  4
#           Park Plaza, Ambala Road, Zirakpur                        3
#           Country Inn & Suites by Radisson, Ambala Road            2
#           Radisson Chandigarh Zirakpur, VIP Road                   2
#           Regenta Almeida Zirakpur, Chandigarh Road, Zirakpur      2
#           Velvet Clarks Exotica, Chandigarh Road, Zirakpur         2
#           Hotel Best Western Maryland, Ambala Road, Zirakpur       1
#           Ramada Plaza, Ambala Road, Zirakpur                      1
# Name: locality, Length: 3858, dtype: int64

# %% [markdown]
# **4. Variable 'latitude'**
#
# From the variable 'latitude', we know the latitudinal location of the restaurant
#
# The Latitudinal extent of India 8º4‛N to 37º6‛ N.
#
# We must check whether we have any points beyond this extent.

# %% [markdown]
# - We need to replace all these values with NaN's.

# %% [markdown]
# - check if the values are replace by NaN's

# %% [markdown]
# - We see all the values are replaced by NaN's

# %%
print(df1['latitude'].dtype)
#(df1['latitude']<8.4) 
invalid_loc=(df1['latitude']<8.4) & (df1['latitude']>37.6)

df1['latitude']=df1['latitude'].replace(invalid_loc,np.nan)
#Find length of such location
print(len(invalid_loc))

df1['latitude'].isnull().sum()
# Out:
# float64
# 50994
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# 946

# %% [markdown]
# **5. Variable 'longitude'**
#
# From the variable 'longitude', we know the longitudinal location of the restaurant
#
# The Longitudinal extent of India is from 68°7'E to 97°25'E
#
# We must check whether we have any points beyond this extent.

# %% [markdown]
# - We need to replace all these values with NaN's.

# %% [markdown]
# - Check if the values are replace by NaN's

# %% [markdown]
# - From variable 'latitude' and 'longitude', plot the location of restaurants.

# %%
print(df1['longitude'].dtype)
 
invalid_loc=(df1['longitude']<68.7) & (df1['longitude']>97.25)

df1['longitude']=df1['longitude'].replace(invalid_loc,np.nan)

print(len(invalid_loc))
df1['longitude'].isnull().sum()
# Out:
# float64
# 50994
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# 954

# %% [markdown]
# **6. Variable 'cuisines'**

# %%
df1['cuisines'].count().sum()
# Out:
# 50524

# %% [markdown]
# - To find the unique cusines we write a small user defined function.

# %%
def cuisine_func(data):
    features=[]
    for i in data.cuisines:
        for j in i.split(','):
            j=j.strip()
            features.append(j)
    return(features)

# %% [markdown]
# - find out the frequency of each cuisine

# %%
data=df1[df1.cuisines.notnull()]
data.highlights=data.cuisines.apply(lambda x:x.lower().strip())
cuisine=cuisine_func(data)
cuisine=pd.Series(cuisine)
cuisine.value_counts()[:10]
# Out:
# North Indian    3709
# Chinese         2569
# Fast Food       1937
# Continental     1452
# Desserts        1301
# Italian         1055
# Beverages       1020
# South Indian     899
# Cafe             857
# Bakery           738
# dtype: int64

# %% [markdown]
# **8. Variable 'average_cost_for_two'**

# %%
print(df1['average_cost_for_two'].value_counts()[:10])
#df1['average_cost_for_two'].isnull().sum()
plt.figure(figsize = (12,8))
df1['average_cost_for_two'].value_counts()[:10].plot(kind = 'pie')
plt.title('Avg cost in Restaurent for 2 people', weight = 'bold')
plt.show()
# Out:
# 200    6202
# 300    5898
# 400    4770
# 100    4531
# 500    4221
# 150    3704
# 250    3233
# 600    2408
# 350    1748
# 800    1727
# Name: average_cost_for_two, dtype: int64

# %% [markdown]
# **9. Variable 'price_range'**

# %%
print(df1['price_range'].value_counts())

print(df1['price_range'].isnull().values.any())

df1['price_range'].plot(kind='hist')
plt.show()
# Out:
# 1    3323
# 2    2881
# 3    1886
# 4     998
# Name: price_range, dtype: int64
# False

# %% [markdown]
# - visualize a exploded pie chart.

# %%
plt.figure(figsize = (12,6))
names = df1['price_range'].value_counts().index
values = df1['price_range'].value_counts().values
explode = (0.1, 0.1, 0.1, 0.1)  # explode 1st slice

colors = ['blue','red','green','yellow','blck','white']
plt.title('Price Range Restaurants', weight = 'bold')
plt.pie(values, explode=explode, labels=names, colors=colors,autopct='%1.1f%%', shadow=True)
plt.axis('equal')
plt.show()

# %% [markdown]
# **10. Variable 'highlights'**

# %%
df1['highlights'].value_counts()[:10]
# Out:
# Dinner, Takeaway Available, Lunch, Cash, Indoor Seating                                                        800
# Dinner, Delivery, Lunch, Cash, Takeaway Available, Indoor Seating                                              515
# Takeaway Available, Cash, Indoor Seating, Desserts and Bakes                                                   361
# Cash, Takeaway Available                                                                                       335
# No Seating Available, Takeaway Available, Cash, Desserts and Bakes                                             320
# Cash                                                                                                           271
# Cash, Takeaway Available, Indoor Seating                                                                       232
# Lunch, Cash, No Alcohol Available, Dinner, Takeaway Available, Indoor Seating                                  190
# Lunch, Cash, Takeaway Available, No Alcohol Available, Dinner, Delivery, Indoor Seating                        187
# Dinner, Cash, Takeaway Available, Debit Card, Lunch, Delivery, Credit Card, Indoor Seating, Air Conditioned    175
# Name: highlights, dtype: int64

# %% [markdown]
# - write a small function to know the number of times a facility has appeared in the 'Highlights'.

# %%
def highlight_func(data):
    features=[]
    for i in data.highlights:
        for j in i.split(','):
            j=j.strip()
            features.append(j)
    return(features)

# %% [markdown]
# - Now we find out which facility occurs most number of in the data.

# %%
data=df1[df1.highlights.notnull()]
data.highlights=data.highlights.apply(lambda x:x.lower().strip())
features=highlight_func(data)
plt.figure(figsize=(12,6)) 
pd.Series(features).value_counts()[:10].plot(kind='bar',color= 'c')
plt.title('Highlights of restaurant',weight='bold')
plt.xlabel('Highlights')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# **11. Variable 'aggregate_rating'**

# %%
average_ratings=df1.groupby(['city'],as_index=False)
avg_agg=average_ratings['aggregate_rating'].agg(np.mean)
print(avg_agg.head())
plt.figure(figsize=(25,10))
plt.xlabel('City', fontsize=20)
plt.ylabel('Average Ratings', fontsize=20)
plt.title('Average Ratings on Cities', fontsize=30)
plt.bar(avg_agg['city'], avg_agg['aggregate_rating'])
plt.xticks(rotation=90)
plt.show()
# Out:
#         city  aggregate_rating
# 0       Agra          3.677419
# 1  Ahmedabad          3.729630
# 2      Ajmer          3.006061
# 3  Allahabad          3.264179
# 4   Amravati          2.825000

# %%
df1['rating_text'].value_counts()
# Out:
# Good             3372
# Very Good        3227
# Average          1611
# Excellent         442
# Not rated         236
# Poor              190
# İyi                 2
# Skvělá volba        1
# Muito Bom           1
# Velmi dobré         1
# Çok iyi             1
# Bardzo dobrze       1
# Baik                1
# Veľmi dobré         1
# Excelente           1
# Name: rating_text, dtype: int64

# %% [markdown]
# Creating a New feature for better understanding of ratings

# %% [markdown]
# **13. Variable 'votes'**

# %%
vote_df=df1.groupby(['city'],as_index=False)['votes'].mean()
print(vote_df.head(10))
vote_df.columns=['City','Mean Votes']
vote10=(vote_df.sort_values(['Mean Votes'],ascending=False)).head(10)
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(x="City",y="Mean Votes",data=vote10)
plt.xlabel('City')
plt.ylabel('Mean Votes')
plt.title('City vs Votes',weight='bold')
plt.show()
# Out:
#            city       votes
# 0          Agra  138.790323
# 1     Ahmedabad  356.029101
# 2         Ajmer   25.181818
# 3     Allahabad   64.343284
# 4      Amravati    7.750000
# 5      Amritsar   87.607143
# 6    Aurangabad   75.214286
# 7     Bangalore  824.151404
# 8        Bhopal  107.647727
# 9  Bhubaneshwar  285.244444

# %% [markdown]
# **14. Variable 'photo_count'**

# %%
print('National mean of photos',df1['photo_count'].mean())
photo_df=df1.groupby(['city'],as_index=False)['photo_count'].mean()
photo_df.columns=['City','Mean Photo Count']
photo10=(photo_df.sort_values(['Mean Photo Count'],ascending=False)).head(10)
print(photo10.head(10))
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(x="City",y="Mean Photo Count",data=photo10)
plt.xlabel('City')
plt.ylabel('Mean Photo Count')
plt.title("Photo Count of Cities",weight='bold')
plt.show()
# Out:
# National mean of photos 326.3261443661972
#            City  Mean Photo Count
# 45      Kolkata        800.624729
# 55       Mumbai        757.224828
# 63    New Delhi        696.436426
# 82        Thane        639.921569
# 25      Gurgaon        610.937107
# 61  Navi Mumbai        549.454545
# 64        Noida        536.971831
# 7     Bangalore        531.039072
# 30    Hyderabad        446.285714
# 71         Pune        398.446646

# %% [markdown]
# **15. Variable 'delivery'**

# %%
border=[0.1,0.2,0.0]
fig,ax=plt.subplots()

df1['delivery'].value_counts().plot(kind='pie',explode=border,autopct="%1.1f%%",ax=ax)
plt.title("Delivery Count for Country Restaurant",weight='bold')
plt.show()
del_df=df1.groupby(['city'],as_index=False)['delivery'].count()
del_df.columns=['City','Delivery']
del10=(del_df.sort_values(['Delivery'],ascending=False)).head(10)
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(x="City",y="Delivery",data=del10)
plt.xlabel('City')
plt.ylabel('Delivery Count')
plt.title("Delivery Count of Cities",weight='bold')
plt.show()
print(del_df.head(5))
# Out:
#         City  Delivery
# 0       Agra        62
# 1  Ahmedabad       378
# 2      Ajmer        33
# 3  Allahabad        67
# 4   Amravati         4

# %% [markdown]
# <a id ='missing'></a>
# ## 6. Check for missing values

# %%
print(df1.isnull().values.any())
df1.dropna(inplace=True)
print(df1.info())
# Out:
# False
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9088 entries, 10 to 211709
# Data columns (total 21 columns):
# res_id                  9088 non-null object
# name                    9088 non-null object
# establishment           9088 non-null object
# address                 9088 non-null object
# city                    9088 non-null object
# city_id                 9088 non-null int64
# locality                9088 non-null object
# latitude                9088 non-null float64
# longitude               9088 non-null float64
# zipcode                 9088 non-null object
# cuisines                9088 non-null object
# timings                 9088 non-null object
# average_cost_for_two    9088 non-null int64
# price_range             9088 non-null int64
# highlights              9088 non-null object
# aggregate_rating        9088 non-null float64
# rating_text             9088 non-null object
# votes                   9088 non-null int64
# photo_count             9088 non-null int64
# delivery                9088 non-null object
# takeaway                9088 non-null object
# dtypes: float64(3), int64(5), object(13)
# memory usage: 1.5+ MB
# None
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# **6. Study summary statistics**

# %% [markdown]
# Let us check the summary statistics for numerical variables.

# %%
df1.describe()
# Out:
#             city_id     latitude    longitude  average_cost_for_two  \
# count   9088.000000  9088.000000  9088.000000           9088.000000
# mean    1109.914723    21.629713    77.433451            818.734045
# std     3343.914464     5.994751     4.248255            892.396154
# min        1.000000     8.430816    44.045241              0.000000
# 25%        4.000000    17.577886    73.878359            300.000000
# 50%        8.000000    22.499841    77.070645            500.000000
# 75%       22.000000    26.867661    78.565718           1000.000000
# max    11354.000000    32.765580    91.811354          30000.000000
#
#        price_range  aggregate_rating         votes   photo_count
# count  9088.000000       9088.000000   9088.000000   9088.000000
# mean      2.061510          3.684078    442.832746    326.326144
# std       1.004371          0.777208    758.126039    672.683096
# min       1.000000          0.000000      0.000000      0.000000
# 25%       1.000000          3.500000     51.000000     19.000000
# 50%       2.000000          3.900000    181.000000     85.000000
# 75%       3.000000          4.100000    524.000000    326.000000
# max       4.000000          4.900000  15705.000000  12736.000000

# %% [markdown]
# <a id = 'correlation'> </a>
# ## 7. Study correlation

# %%
df1.corr()
# Out:
#                        city_id  latitude  longitude  average_cost_for_two  \
# city_id               1.000000  0.121627   0.022813             -0.142501
# latitude              0.121627  1.000000   0.056983             -0.060300
# longitude             0.022813  0.056983   1.000000             -0.049466
# average_cost_for_two -0.142501 -0.060300  -0.049466              1.000000
# price_range          -0.141937 -0.076714  -0.050796              0.765254
# aggregate_rating     -0.179870 -0.065811  -0.009129              0.198871
# votes                -0.162231 -0.101018  -0.009511              0.165237
# photo_count          -0.148175 -0.062617   0.015055              0.234827
#
#                       price_range  aggregate_rating     votes  photo_count
# city_id                 -0.141937         -0.179870 -0.162231    -0.148175
# latitude                -0.076714         -0.065811 -0.101018    -0.062617
# longitude               -0.050796         -0.009129 -0.009511     0.015055
# average_cost_for_two     0.765254          0.198871  0.165237     0.234827
# price_range              1.000000          0.231667  0.197954     0.277082
# aggregate_rating         0.231667          1.000000  0.317289     0.303667
# votes                    0.197954          0.317289  1.000000     0.737178
# photo_count              0.277082          0.303667  0.737178     1.000000

# %% [markdown]
# <a id='outliers'> </a>
# ## 8. Detect outliers

# %%
#Detecting by IQR
Q1=df1.quantile(0.25)
Q3=df1.quantile(0.75)
IQR=Q3-Q1
print(IQR)

#sns.boxplot(x='city_id',y='name',data=df1)
#plt.show()
# Out:
# city_id                  18.000000
# latitude                  9.289774
# longitude                 4.687359
# average_cost_for_two    700.000000
# price_range               2.000000
# aggregate_rating          0.600000
# votes                   473.000000
# photo_count             307.000000
# dtype: float64

# %% [markdown]
# <a id='region'> </a>
# ## 9. Create a new variable 'region'

# %% [markdown]
# Create a variable 'region' with four categories 'northern','eastern', 'southern', 'western' and 'central'. To do so, use the 'city' column, group all cities belonging to the same region.

# %%
def splitDataFrameIntoSmaller(df1, chunkSize = 1019): 
    listOfDf = list()
    numberChunks = len(df1) // chunkSize + 1
    for i in range(numberChunks):
        listOfDf.append(df1[i*chunkSize:(i+1)*chunkSize])
    return listOfDf


df_list=splitDataFrameIntoSmaller(df1)
df_list[0].head()
df_list[0]['region']='north'
df_list[1]['region']='south'
df_list[2]['region']='west'
df_list[3]['region']='central'
df_list[4]['region']='east'

region_df=pd.DataFrame()

region_df=region_df.append(df_list)
region_df.head(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
#                                               address  aggregate_rating  \
# 10  6/27/1A, Hotel Alleviate, Yamuna Kinara Road, ...               4.4
# 11  Opposite ITC Mughal, Fatehbad Road, Tajganj, Agra               4.4
# 19                                      Delhi Gate Rd               4.4
# 23     Opposite ISBT, Transport Nagar, Sikandra, Agra               4.2
# 25  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...               4.3
#
#     average_cost_for_two  city  city_id  \
# 10                  1200  Agra       34
# 11                   700  Agra       34
# 19                   300  Agra       34
# 23                   200  Agra       34
# 25                   400  Agra       34
#
#                                              cuisines delivery  establishment  \
# 10                 Continental, North Indian, Chinese        1  Casual Dining
# 11  North Indian, South Indian, Mithai, Street Foo...        1  Casual Dining
# 19              Fast Food, Wraps, Desserts, Beverages        1    Quick Bites
# 23                                       North Indian        1     Bhojanalya
# 25                                         Rajasthani        1  Casual Dining
#
#                                            highlights   latitude   ...    \
# 10  Dinner, Delivery, Credit Card, Lunch, Serves A...  27.190041   ...
# 11  Dinner, Delivery, Breakfast, Lunch, Cash, Take...  27.158549   ...
# 19  Cash, Delivery, No Alcohol Available, Dinner, ...  27.197103   ...
# 23  Cash, Debit Card, Takeaway Available, Lunch, D...  27.208142   ...
# 25  Takeaway Available, Dinner, Delivery, Lunch, I...  27.195759   ...
#
#                                      name  photo_count price_range  \
# 10                                Hichkee          229           3
# 11                            Bikanervala          162           2
# 19                       The Greener Side           77           1
# 23                        Jain Bhojnalaya            3           1
# 25  Chokho Jeeman Marwari Jain Bhojanalya          109           2
#
#     rating_text  region   res_id takeaway  \
# 10    Very Good   north  3400868       -1
# 11    Very Good   north  3400425       -1
# 19    Very Good   north  3400712       -1
# 23    Very Good   north  3401687       -1
# 25    Very Good   north  3400021       -1
#
#                                   timings votes zipcode
# 10                    4pm – 1am (Mon-Sun)   683  282002
# 11             8:30am – 10:30pm (Mon-Sun)   523  282001
# 19                   1pm – 10pm (Mon-Sun)   490  282002
# 23                   10am – 3am (Mon-Sun)   237  282007
# 25  11AM to 3:15PM, 7PM to 10PM (Mon-Sun)   514  282002
#
# [5 rows x 22 columns]

# %%
group_city=region_df.groupby(['region'],as_index=False)['city'].count()
group_city.columns=['Region','City']
print(group_city)
# Out:
#     Region  City
# 0  central  1019
# 1     east  1019
# 2    north  1019
# 3    south  1019
# 4     west  1019

# %% [markdown]
# <a id='more'> </a>
# ## 10. Some more Analysis

# %% [markdown]
# <b>Lets us explore the data some more now that we have extrapolated and removed the missing values <br>
# We now conduct analysis to compare the regions.</b>

# %% [markdown]
# ### 1. To find which cities have expensive restaurants
#
# -  plot the cities which have costliest restaurants.

# %%
df_exp=df1[df1['price_range']>3]
df_exp['city'].value_counts()[:10].plot(kind='barh')
plt.xlabel("Count of restaurant")
plt.ylabel('City')
plt.title('Cities with expensive restaurant')
plt.show()

# %% [markdown]
# ### 2.  Comparing regions

# %%
region_df.groupby('region').describe()
# Out:
#         aggregate_rating                                               \
#                    count      mean       std  min  25%  50%  75%  max
# region
# central           1019.0  3.760844  0.714354  0.0  3.6  3.9  4.2  4.9
# east              1019.0  3.567615  0.793881  0.0  3.3  3.7  4.0  4.9
# north             1019.0  3.689500  0.887635  0.0  3.5  3.9  4.2  4.9
# south             1019.0  3.769578  0.657821  0.0  3.6  3.9  4.1  4.9
# west              1019.0  3.771933  0.563770  0.0  3.6  3.9  4.1  4.9
#
#         average_cost_for_two                ...    price_range        votes  \
#                        count         mean   ...            75%  max   count
# region                                      ...
# central               1019.0  1062.109912   ...            3.0  4.0  1019.0
# east                  1019.0   693.905790   ...            2.0  4.0  1019.0
# north                 1019.0   765.996075   ...            3.0  4.0  1019.0
# south                 1019.0   763.052012   ...            3.0  4.0  1019.0
# west                  1019.0  1018.644750   ...            3.0  4.0  1019.0
#
#
#                mean          std  min   25%    50%    75%      max
# region
# central  513.119725   847.511128  0.0  60.0  206.0  600.5  10953.0
# east     254.760550   396.944629  0.0  31.0   97.0  312.5   3441.0
# north    530.846909  1145.363953  0.0  58.0  188.0  589.5  15705.0
# south    460.611384   686.263169  0.0  68.0  218.0  575.5   8624.0
# west     476.708538   674.844214  0.0  85.5  255.0  583.0   6323.0
#
# [5 rows x 64 columns]

# %% [markdown]
# ### 2a. Highlights available in restaurants for different regions

# %% [markdown]
# To cater our analysis we define the regions as nothern, eastern, western and southern.

# %% [markdown]
# We first need to select the unique facilities available in each region and sort according to their frequencies.

# %% [markdown]
# **Highlights of the northern region**

# %%
def highlight_func(data):
    features=[]
    for i in data.highlights:
        for j in i.split(','):
            j=j.strip()
            features.append(j)
    return(features)

# %%
feature=list()
data=df_list[0][df_list[0].highlights.notnull()]
data.highlights=data.highlights.apply(lambda x:x.lower().strip())
f1=highlight_func(data)
feature.extend(set(f1))

data=df_list[1][df_list[1].highlights.notnull()]
data.highlights=data.highlights.apply(lambda x:x.lower().strip())
f2=highlight_func(data)
feature.extend(set(f2))

data=df_list[2][df_list[2].highlights.notnull()]
data.highlights=data.highlights.apply(lambda x:x.lower().strip())
f3=highlight_func(data)
feature.extend(set(f3))

data=df_list[3][df_list[3].highlights.notnull()]
data.highlights=data.highlights.apply(lambda x:x.lower().strip())
f4=highlight_func(data)
feature.extend(set(f4))

data=df_list[4][df_list[4].highlights.notnull()]
data.highlights=data.highlights.apply(lambda x:x.lower().strip())
f5=highlight_func(data)
feature.extend(set(f5))

# %%
north=list(set(f1)-(set(f2)-set(f3)-set(f4)-set(f5)))

# %% [markdown]
# **Highlights of the eastern region**

# %%
east=list(set(f5)-(set(f2)-set(f3)-set(f4)-set(f1)))

# %% [markdown]
# **Highlights of the southern region**

# %%
south=list(set(f2)-(set(f5)-set(f3)-set(f4)-set(f1)))

# %% [markdown]
# **Highlights of the western region**

# %%
west=list(set(f3)-(set(f5)-set(f2)-set(f4)-set(f1)))

# %% [markdown]
# #### Plot the barplot for different regions

# %% [markdown]
# We shall now plot the graphs for top 10 highlights.

# %%
comm=list()
comm.extend(north)
comm.extend(south)
comm.extend(west)
comm.extend(east)

c=pd.Series(comm)
c.column=['High']
c.value_counts()[:10].plot(kind='bar')

plt.xlabel('Locality')
plt.ylabel('Count of highlight')
plt.title("Top 10 Highlights ",weight='bold')
#plt.show()
# Out:
# Text(0.5,1,'Top 10 Highlights ')

# %% [markdown]
# ### 2b. Cuisines available in restaurants for different regions

# %% [markdown]
# **Cuisines in the northern region**

# %%
def cuisine_func(data):
    features=[]
    for i in data.cuisines:
        for j in i.split(','):
            j=j.strip()
            features.append(j)
    return(features)

# %%
feature=list()
data=df_list[0][df_list[0].cuisines.notnull()]
data.cuisines=data.cuisines.apply(lambda x:x.lower().strip())
f1=cuisine_func(data)
feature.extend(set(f1))

data=df_list[1][df_list[1].cuisines.notnull()]
data.cuisines=data.cuisines.apply(lambda x:x.lower().strip())
f2=cuisine_func(data)
feature.extend(set(f2))

data=df_list[2][df_list[2].cuisines.notnull()]
data.cuisines=data.cuisines.apply(lambda x:x.lower().strip())
f3=cuisine_func(data)
feature.extend(set(f3))

data=df_list[3][df_list[3].cuisines.notnull()]
data.cuisines=data.cuisines.apply(lambda x:x.lower().strip())
f4=cuisine_func(data)
feature.extend(set(f4))

data=df_list[4][df_list[4].cuisines.notnull()]
data.cuisines=data.cuisines.apply(lambda x:x.lower().strip())
f5=cuisine_func(data)
feature.extend(set(f5))

# %%
print(set(f1))
# Out:
# {'hyderabadi', 'american', 'beverages', 'finger food', 'burger', 'rolls', 'afghan', 'konkan', 'modern indian', 'bengali', 'frozen yogurt', 'desserts', 'coffee', 'italian', 'french', 'north indian', 'juices', 'mexican', 'momos', 'andhra', 'arabian', 'pakistani', 'lebanese', 'asian', 'sushi', 'indian', 'sindhi', 'healthy food', 'wraps', 'korean', 'mithai', 'lucknowi', 'drinks only', 'pizza', 'tex-mex', 'japanese', 'malwani', 'burmese', 'salad', 'chinese', 'charcoal chicken', 'paan', 'rajasthani', 'thai', 'maharashtrian', 'street food', 'cafe', 'sandwich', 'gujarati', 'fast food', 'ice cream', 'greek', 'vietnamese', 'bakery', 'bar food', 'kerala', 'bbq', 'tibetan', 'mediterranean', 'tea', 'mangalorean', 'kebab', 'kashmiri', 'continental', 'biryani', 'goan', 'south indian', 'spanish', 'mughlai', 'seafood', 'european', 'steak'}

# %% [markdown]
# **Cuisines in the eastern region**

# %%
print(set(f5))
# Out:
# {'hyderabadi', 'american', 'beverages', 'finger food', 'burger', 'rolls', 'afghan', 'modern indian', 'frozen yogurt', 'desserts', 'coffee', 'italian', 'north indian', 'momos', 'mexican', 'juices', 'andhra', 'parsi', 'asian', 'lebanese', 'indian', 'healthy food', 'wraps', 'mithai', 'pizza', 'cantonese', 'coffee and tea', 'belgian', 'salad', 'cuisine varies', 'chinese', 'charcoal chicken', 'paan', 'thai', 'rajasthani', 'iranian', 'maharashtrian', 'cafe', 'street food', 'sandwich', 'gujarati', 'fast food', 'ice cream', 'bar food', 'bakery', 'roast chicken', 'bbq', 'mediterranean', 'tea', 'crepes', 'bihari', 'kebab', 'kashmiri', 'bubble tea', 'continental', 'biryani', 'raw meats', 'south indian', 'seafood', 'mughlai', 'european', 'steak'}

# %% [markdown]
# **Cuisines in the southern region**

# %%
print(set(f2))
# Out:
# {'hyderabadi', 'singaporean', 'american', 'beverages', 'finger food', 'burger', 'afghan', 'rolls', 'konkan', 'modern indian', 'turkish', 'bengali', 'desserts', 'coffee', 'odia', 'italian', 'french', 'north indian', 'momos', 'juices', 'mexican', 'andhra', 'arabian', 'pan asian', 'oriental', 'asian', 'lebanese', 'awadhi', 'sushi', 'indian', 'cafe food', 'sindhi', 'healthy food', 'wraps', 'korean', 'mithai', 'middle eastern', 'lucknowi', 'pizza', 'japanese', 'burmese', 'cantonese', 'salad', 'chettinad', 'chinese', 'mishti', 'paan', 'rajasthani', 'thai', 'maharashtrian', 'cafe', 'street food', 'sandwich', 'gujarati', 'indonesian', 'fast food', 'ice cream', 'bar food', 'vietnamese', 'bakery', 'kerala', 'bbq', 'mediterranean', 'tea', 'malaysian', 'mangalorean', 'kebab', 'continental', 'biryani', 'german', 'south indian', 'goan', 'seafood', 'mughlai', 'raw meats', 'european', 'steak'}

# %% [markdown]
# **Cuisines in the western region**

# %%
print(set(f3))
# Out:
# {'singaporean', 'american', 'beverages', 'finger food', 'burger', 'rolls', 'turkish', 'afghan', 'bengali', 'modern indian', 'frozen yogurt', 'desserts', 'coffee', 'moroccan', 'italian', 'french', 'north indian', 'momos', 'mexican', 'arabian', 'andhra', 'juices', 'british', 'fusion', 'parsi', 'modern australian', 'asian', 'lebanese', 'awadhi', 'sushi', 'indian', 'healthy food', 'korean', 'wraps', 'mithai', 'middle eastern', 'drinks only', 'pizza', 'lucknowi', 'japanese', 'tex-mex', 'belgian', 'chettinad', 'salad', 'chinese', 'charcoal chicken', 'thai', 'iranian', 'rajasthani', 'maharashtrian', 'street food', 'cafe', 'sandwich', 'gujarati', 'indonesian', 'fast food', 'ice cream', 'vietnamese', 'bar food', 'bakery', 'grill', 'irish', 'kerala', 'bbq', 'sri lankan', 'mediterranean', 'malaysian', 'mangalorean', 'tea', 'kebab', 'bubble tea', 'continental', 'biryani', 'spanish', 'south indian', 'raw meats', 'seafood', 'mughlai', 'european', 'steak'}

# %% [markdown]
# - Plot the barplot for top 10 cuisines served in the four regions

# %%
common_cuisine=list()

common_cuisine.extend(f1)
common_cuisine.extend(f2)
common_cuisine.extend(f3)
common_cuisine.extend(f5)

comm=pd.Series(common_cuisine)
comm.columns=['Cuisine']
comm.value_counts()[:10].plot(kind='bar')

plt.xlabel('Cuisine')
plt.ylabel('Number')
plt.title('Top 10 cuisines across region',weight='bold')
# Out:
# Text(0.5,1,'Top 10 cuisines across region')

# %% [markdown]
# ###  3. The Northern Region

# %% [markdown]
# **Now we shall consider only the northern region**

# %% [markdown]
# **1. The top 10 cuisines served in Restaurants**

# %%
cuisine_count = []

for i in df_list[0].cuisines:
    for t in i.split(','):
        t = t.strip()
        cuisine_count.append(t)


plt.figure(figsize=(12,6))
pd.Series(cuisine_count).value_counts()[:10].plot(kind='bar',color= 'c')
plt.title('Top 10 cuisines in North Area',weight='bold')
plt.xlabel('Cuisine')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **2. Do restaurants with more photo counts and votes have better rating?**

# %%
plt.figure(figsize = (12,6))
sns.barplot(x='aggregate_rating',y='photo_count',data=df_list[0])
plt.xlabel("Rating")
plt.ylabel("Photo Count")
plt.title("Rating Trend with Photo",weight = 'bold')
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.barplot(x='aggregate_rating',y='votes',data=df_list[0])
plt.xlabel("Rating")
plt.ylabel("Votes")
plt.title("Rating Trend with Votes",weight = 'bold')
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.boxplot(x='aggregate_rating',y='votes',data=df_list[0])
plt.xlabel("Rating")
plt.ylabel("Votes")
plt.title("Rating Trend with Votes",weight = 'bold')
plt.show()

# %% [markdown]
# - Plot a boxplots for the above table

# %% [markdown]
# ### 4. The Mumbai city

# %% [markdown]
# consider the city mumbai and get a better insights of restuarants in Mumbai.

# %%
new_df=region_df[region_df['city']=='Mumbai']

# %% [markdown]
# **1. Expensive restaurants in Mumbai**
#
# -  Define the costliest restaurants whose average cost of two people exceeds Rs.5000 .
# -  Plot the restaurants which are costliest based on their average cost for two .

# %%
expensive=new_df[new_df['average_cost_for_two']>5000]


new=new_df.groupby(['name'],as_index=False)['average_cost_for_two'].sum()
new.columns=['Name',"Cost"]
costly=(new.sort_values(['Cost'],ascending=False)).head(20)
print(costly.head())

sns.barplot(y='Cost',x='Name',data=costly)
plt.xlabel("Reataurant Name")
plt.ylabel("Avg.Cost")
plt.title("Costly Restaurant in Mumbai",weight="bold")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **2.To find the top 20 cuisines of Mumbai**

# %% [markdown]
# - select unique cuisines available at restaurants in Mumbai
#
#
# - sort cuisines based on frequency

# %%
cuisines= []

for i in new_df.cuisines:
    for j in i.split(','):
        j = j.strip()
        cuisines.append(j)
        
        
plt.figure(figsize=(12,6)) 
pd.Series(cuisines).value_counts()[:20].plot(kind='bar',color= 'r')
plt.title('Top 10 cuisines in Mumbai',weight='bold')
plt.xlabel('cuisines type')
plt.ylabel('No of restaurants')
plt.show()

# %% [markdown]
# **3. To find the popular localities in Mumbai**

# %%
new_df['locality'].value_counts()

# Checking Popularity of a locality by calculating average rating of all restaurants present in that locality.
pop_loc=new_df.groupby(['locality'],as_index=False)['aggregate_rating'].mean()
pop_loc.columns=['Locality','Rating']
loc_df=(pop_loc.sort_values(['Rating'],ascending=False)).head(10)

sns.barplot(x='Locality',y='Rating',data=loc_df)
plt.xticks(rotation=90)
plt.title("Popular Locality in Mumbai")
plt.show()

# %% [markdown]
# **4. Check for relationship between 'aggregate_rating' and 'average_cost_for_two'**

# %%
plt.xlabel('Rating')
plt.ylabel('Average Cost for two(In Indian Rupees)')
plt.title('Rating vs Avg. Cost for Two')
sns.pointplot(x='aggregate_rating',y='average_cost_for_two',data=new_df,ci=False)
plt.show()

# %% [markdown]
# **5. Multiple box plot for photo_counts based on establishment type.**

# %%
plt.xlabel('Establishment')
plt.ylabel('Photo Count')
plt.title('Rating vs Avg. Cost for Two')
sns.boxplot(x='establishment',y='photo_count',data=new_df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **6. Check for payments method offered in restaurants**

# %% [markdown]
# - select unique facilities available at restaurants in western region
# - sort facilities based on frequency

# %%
west_df=region_df[region_df['region']=='west']
west_feature=highlight_func(west_df)
west_feature=pd.DataFrame(west_feature)
west_feature.columns=['Highlight']
l=list(west_feature['Highlight'].unique())
print("There are ",len(l)," unique facilities available")
